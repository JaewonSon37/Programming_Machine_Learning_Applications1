# %%
import numpy as np
import pandas as pd

# %%
pop_df = pd.read_csv("C:\\Users\\wodnj\\OneDrive\\바탕 화면\\Programming Machine Learning Applications\\DSC 478 - Week 2\\Data File\\populations.txt", sep='\t')
pop_df
# Out:
#     year     hare     lynx  carrot
# 0   1900  30000.0   4000.0   48300
# 1   1901  47200.0   6100.0   48200
# 2   1902  70200.0   9800.0   41500
# 3   1903  77400.0  35200.0   38200
# 4   1904  36300.0  59400.0   40600
# 5   1905  20600.0  41700.0   39800
# 6   1906  18100.0  19000.0   38600
# 7   1907  21400.0  13000.0   42300
# 8   1908  22000.0   8300.0   44500
# 9   1909  25400.0   9100.0   42100
# 10  1910  27100.0   7400.0   46000
# 11  1911  40300.0   8000.0   46800
# 12  1912  57000.0  12300.0   43800
# 13  1913  76600.0  19500.0   40900
# 14  1914  52300.0  45700.0   39400
# 15  1915  19500.0  51100.0   39000
# 16  1916  11200.0  29700.0   36700
# 17  1917   7600.0  15800.0   41800
# 18  1918  14600.0   9700.0   43300
# 19  1919  16200.0  10100.0   41300
# 20  1920  24700.0   8600.0   47300

# %%
pop_df.head(7)
# Out:
#    year     hare     lynx  carrot
# 0  1900  30000.0   4000.0   48300
# 1  1901  47200.0   6100.0   48200
# 2  1902  70200.0   9800.0   41500
# 3  1903  77400.0  35200.0   38200
# 4  1904  36300.0  59400.0   40600
# 5  1905  20600.0  41700.0   39800
# 6  1906  18100.0  19000.0   38600

# %%
pop_df.columns
# Out:
# Index(['year', 'hare', 'lynx', 'carrot'], dtype='object')

# %%
pop_df.values
# Out:
# array([[ 1900., 30000.,  4000., 48300.],
#        [ 1901., 47200.,  6100., 48200.],
#        [ 1902., 70200.,  9800., 41500.],
#        [ 1903., 77400., 35200., 38200.],
#        [ 1904., 36300., 59400., 40600.],
#        [ 1905., 20600., 41700., 39800.],
#        [ 1906., 18100., 19000., 38600.],
#        [ 1907., 21400., 13000., 42300.],
#        [ 1908., 22000.,  8300., 44500.],
#        [ 1909., 25400.,  9100., 42100.],
#        [ 1910., 27100.,  7400., 46000.],
#        [ 1911., 40300.,  8000., 46800.],
#        [ 1912., 57000., 12300., 43800.],
#        [ 1913., 76600., 19500., 40900.],
#        [ 1914., 52300., 45700., 39400.],
#        [ 1915., 19500., 51100., 39000.],
#        [ 1916., 11200., 29700., 36700.],
#        [ 1917.,  7600., 15800., 41800.],
#        [ 1918., 14600.,  9700., 43300.],
#        [ 1919., 16200., 10100., 41300.],
#        [ 1920., 24700.,  8600., 47300.]])

# %%
pop_df.dtypes
# Out:
# year        int64
# hare      float64
# lynx      float64
# carrot      int64
# dtype: object

# %%
hare_df = pop_df["hare"]
hare_df
# Out:
# 0     30000.0
# 1     47200.0
# 2     70200.0
# 3     77400.0
# 4     36300.0
# 5     20600.0
# 6     18100.0
# 7     21400.0
# 8     22000.0
# 9     25400.0
# 10    27100.0
# 11    40300.0
# 12    57000.0
# 13    76600.0
# 14    52300.0
# 15    19500.0
# 16    11200.0
# 17     7600.0
# 18    14600.0
# 19    16200.0
# 20    24700.0
# Name: hare, dtype: float64

# %%
print(type(pop_df.hare))
# Out:
# <class 'pandas.core.series.Series'>

# %%
print("Mean Hare Population: ", hare_df.mean())
# Out:
# Mean Hare Population:  34080.95238095238

# %%
print("Mean Populations: \n")
print(pop_df[["hare", "lynx", "carrot"]].mean())
print("\n")
print("Standard Deviations: \n")
print(pop_df[["hare", "lynx", "carrot"]].std())
# Out:
# Mean Populations:
#
# hare      34080.952381
# lynx      20166.666667
# carrot    42400.000000
# dtype: float64
#
#
# Standard Deviations:
#
# hare      21413.981859
# lynx      16655.999920
# carrot     3404.555771
# dtype: float64

# %%
pop_df[["hare", "lynx", "carrot"]].describe()
# Out:
#                hare          lynx        carrot
# count     21.000000     21.000000     21.000000
# mean   34080.952381  20166.666667  42400.000000
# std    21413.981859  16655.999920   3404.555771
# min     7600.000000   4000.000000  36700.000000
# 25%    19500.000000   8600.000000  39800.000000
# 50%    25400.000000  12300.000000  41800.000000
# 75%    47200.000000  29700.000000  44500.000000
# max    77400.000000  59400.000000  48300.000000

# %%
pop_df.describe()
# Out:
#               year          hare          lynx        carrot
# count    21.000000     21.000000     21.000000     21.000000
# mean   1910.000000  34080.952381  20166.666667  42400.000000
# std       6.204837  21413.981859  16655.999920   3404.555771
# min    1900.000000   7600.000000   4000.000000  36700.000000
# 25%    1905.000000  19500.000000   8600.000000  39800.000000
# 50%    1910.000000  25400.000000  12300.000000  41800.000000
# 75%    1915.000000  47200.000000  29700.000000  44500.000000
# max    1920.000000  77400.000000  59400.000000  48300.000000

# %%
pop_df[["hare", "lynx", "carrot"]].corr()
# Out:
#             hare      lynx    carrot
# hare    1.000000  0.071892 -0.016604
# lynx    0.071892  1.000000 -0.680577
# carrot -0.016604 -0.680577  1.000000

# %%
pop_df.sort_values(by = ['hare'], ascending = False)
# Out:
#     year     hare     lynx  carrot
# 3   1903  77400.0  35200.0   38200
# 13  1913  76600.0  19500.0   40900
# 2   1902  70200.0   9800.0   41500
# 12  1912  57000.0  12300.0   43800
# 14  1914  52300.0  45700.0   39400
# 1   1901  47200.0   6100.0   48200
# 11  1911  40300.0   8000.0   46800
# 4   1904  36300.0  59400.0   40600
# 0   1900  30000.0   4000.0   48300
# 10  1910  27100.0   7400.0   46000
# 9   1909  25400.0   9100.0   42100
# 20  1920  24700.0   8600.0   47300
# 8   1908  22000.0   8300.0   44500
# 7   1907  21400.0  13000.0   42300
# 5   1905  20600.0  41700.0   39800
# 15  1915  19500.0  51100.0   39000
# 6   1906  18100.0  19000.0   38600
# 19  1919  16200.0  10100.0   41300
# 18  1918  14600.0   9700.0   43300
# 16  1916  11200.0  29700.0   36700
# 17  1917   7600.0  15800.0   41800

# %%
hare_above_50K = pop_df.hare > 50000

print(hare_above_50K)
print("\n")
print(pop_df[hare_above_50K])
print("\n")
print(pop_df[hare_above_50K].year)
# Out:
# 0     False
# 1     False
# 2      True
# 3      True
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12     True
# 13     True
# 14     True
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# Name: hare, dtype: bool
#
#
#     year     hare     lynx  carrot
# 2   1902  70200.0   9800.0   41500
# 3   1903  77400.0  35200.0   38200
# 12  1912  57000.0  12300.0   43800
# 13  1913  76600.0  19500.0   40900
# 14  1914  52300.0  45700.0   39400
#
#
# 2     1902
# 3     1903
# 12    1912
# 13    1913
# 14    1914
# Name: year, dtype: int64

# %%
above_50K = (pop_df["hare"] > 50000) | (pop_df["lynx"] > 50000)
pop_df[above_50K]
# Out:
#     year     hare     lynx  carrot
# 2   1902  70200.0   9800.0   41500
# 3   1903  77400.0  35200.0   38200
# 4   1904  36300.0  59400.0   40600
# 12  1912  57000.0  12300.0   43800
# 13  1913  76600.0  19500.0   40900
# 14  1914  52300.0  45700.0   39400
# 15  1915  19500.0  51100.0   39000

# %%
pop2 = pop_df.drop("year", axis = 1)
pop2
# Out:
#        hare     lynx  carrot
# 0   30000.0   4000.0   48300
# 1   47200.0   6100.0   48200
# 2   70200.0   9800.0   41500
# 3   77400.0  35200.0   38200
# 4   36300.0  59400.0   40600
# 5   20600.0  41700.0   39800
# 6   18100.0  19000.0   38600
# 7   21400.0  13000.0   42300
# 8   22000.0   8300.0   44500
# 9   25400.0   9100.0   42100
# 10  27100.0   7400.0   46000
# 11  40300.0   8000.0   46800
# 12  57000.0  12300.0   43800
# 13  76600.0  19500.0   40900
# 14  52300.0  45700.0   39400
# 15  19500.0  51100.0   39000
# 16  11200.0  29700.0   36700
# 17   7600.0  15800.0   41800
# 18  14600.0   9700.0   43300
# 19  16200.0  10100.0   41300
# 20  24700.0   8600.0   47300

# %%
poptable = np.array(pop2)
poptable
# Out:
# array([[30000.,  4000., 48300.],
#        [47200.,  6100., 48200.],
#        [70200.,  9800., 41500.],
#        [77400., 35200., 38200.],
#        [36300., 59400., 40600.],
#        [20600., 41700., 39800.],
#        [18100., 19000., 38600.],
#        [21400., 13000., 42300.],
#        [22000.,  8300., 44500.],
#        [25400.,  9100., 42100.],
#        [27100.,  7400., 46000.],
#        [40300.,  8000., 46800.],
#        [57000., 12300., 43800.],
#        [76600., 19500., 40900.],
#        [52300., 45700., 39400.],
#        [19500., 51100., 39000.],
#        [11200., 29700., 36700.],
#        [ 7600., 15800., 41800.],
#        [14600.,  9700., 43300.],
#        [16200., 10100., 41300.],
#        [24700.,  8600., 47300.]])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(pop_df["year"], pop_df["hare"])

# %%
plt.plot(pop_df["year"], pop2, label = ['Hares','Lynxes','Carrots'])
plt.legend(('Hares','Lynxes','Carrots'))
plt.ylabel('Population')
plt.xlabel('Year')
plt.show()

# %%
plt.hist(pop_df["carrot"], bins = 8, alpha = 0.5)
plt.xlabel('Carrots')
plt.ylabel('Count')
plt.title('Histogram of Carrot Populaions')
plt.axis([36000, 49000, 0, 6])
plt.grid(True)

# %%
pop_df.plot(x = "year", title = "Populations")
# Out:
# <Axes: title={'center': 'Populations'}, xlabel='year'>

# %%
pop_df.plot(x = "carrot", y = "lynx", kind = "scatter")
# Out:
# <Axes: xlabel='carrot', ylabel='lynx'>

# %%
pop_df.boxplot(column = ["hare", "lynx", "carrot"], return_type = 'axes')
# Out:
# <Axes: >

# %%
fox_col = np.random.randint(low = 5000, high = 20000, size = 21)
fox_col
# Out:
# array([16053, 19132,  8207, 16666, 16289,  6378,  8829, 15530, 15586,
#        14911, 14441, 15547,  9859,  9189,  6636, 11936,  5522, 15902,
#        19450,  7619,  5913])

# %%
pop_df["fox"] = pd.Series(fox_col, index = pop_df.index)
pop_df
# Out:
#     year     hare     lynx  carrot    fox
# 0   1900  30000.0   4000.0   48300  16053
# 1   1901  47200.0   6100.0   48200  19132
# 2   1902  70200.0   9800.0   41500   8207
# 3   1903  77400.0  35200.0   38200  16666
# 4   1904  36300.0  59400.0   40600  16289
# 5   1905  20600.0  41700.0   39800   6378
# 6   1906  18100.0  19000.0   38600   8829
# 7   1907  21400.0  13000.0   42300  15530
# 8   1908  22000.0   8300.0   44500  15586
# 9   1909  25400.0   9100.0   42100  14911
# 10  1910  27100.0   7400.0   46000  14441
# 11  1911  40300.0   8000.0   46800  15547
# 12  1912  57000.0  12300.0   43800   9859
# 13  1913  76600.0  19500.0   40900   9189
# 14  1914  52300.0  45700.0   39400   6636
# 15  1915  19500.0  51100.0   39000  11936
# 16  1916  11200.0  29700.0   36700   5522
# 17  1917   7600.0  15800.0   41800  15902
# 18  1918  14600.0   9700.0   43300  19450
# 19  1919  16200.0  10100.0   41300   7619
# 20  1920  24700.0   8600.0   47300   5913

# %%
pop_df.plot(x = "year", y = "fox", kind = "area", title = "Fox Population")
# Out:
# <Axes: title={'center': 'Fox Population'}, xlabel='year'>

# %%
pd.plotting.scatter_matrix(pop_df[["hare", "lynx", "carrot"]], figsize = (14, 14), hist_kwds = {'bins':8}, alpha = 0.5, marker = 'o', s = 50)
# Out:
# array([[<Axes: xlabel='hare', ylabel='hare'>,
#         <Axes: xlabel='lynx', ylabel='hare'>,
#         <Axes: xlabel='carrot', ylabel='hare'>],
#        [<Axes: xlabel='hare', ylabel='lynx'>,
#         <Axes: xlabel='lynx', ylabel='lynx'>,
#         <Axes: xlabel='carrot', ylabel='lynx'>],
#        [<Axes: xlabel='hare', ylabel='carrot'>,
#         <Axes: xlabel='lynx', ylabel='carrot'>,
#         <Axes: xlabel='carrot', ylabel='carrot'>]], dtype=object)
